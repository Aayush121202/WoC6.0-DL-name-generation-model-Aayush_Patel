# %% [markdown]
# **Loading Dataset.**

# %%
import re

# %%
import numpy
import random

# %%
data = open('/content/dataset (1).txt', 'r').read()

# %%
# Change all uppercase letters to lowercase
data = data.lower()

# %%
# Split the data by '\n'
words = data.split('\n')

# Define a regular expression pattern to match special characters
pattern = re.compile('[^a-zA-Z\n]')

# Filter out words with special characters and keep '\n' as a separator
filtered_words = [word for word in words if not pattern.search(word)]

# Join the filtered words back together with '\n' as a separator
filtered_data = '\n'.join(filtered_words)

print(filtered_data)

filtered_chars = list(set(filtered_data))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
data_size, vocab_size = len(filtered_data), len(filtered_chars)

# %%
print('data has %d characters, %d unique.' % (data_size, vocab_size))
# Out:
# data has 7300255 characters, 27 unique.

# %%
# Convert the filtered data into a list of names
names = filtered_data.split()

# Extract a sample of 10 names
sample_size = 10
sample_names = random.sample(names, sample_size)

# Print the sample names
for name in sample_names:
    print(name)
# Out:
# dean
# georgie
# jasson
# samaria
# breann
# regina
# melanie
# rebecca
# hayes
# evangelina

# %% [markdown]
# **Creating Dictionaries.**

# %%
char_to_ix = { ch:i for i,ch in enumerate(filtered_chars) }
ix_to_char = { i:ch for i,ch in enumerate(filtered_chars) }

# %%
print(char_to_ix)
# Out:
# {'y': 0, 'c': 1, 'q': 2, 'w': 3, 'x': 4, 'n': 5, 'z': 6, 'b': 7, 'r': 8, 'h': 9, 'p': 10, 'd': 11, 'j': 12, 'a': 13, 't': 14, 's': 15, 'i': 16, 'v': 17, 'l': 18, 'g': 19, 'u': 20, 'e': 21, 'f': 22, 'k': 23, 'o': 24, 'm': 25, '\n': 26}

# %%
print(ix_to_char)
# Out:
# {0: 'y', 1: 'c', 2: 'q', 3: 'w', 4: 'x', 5: 'n', 6: 'z', 7: 'b', 8: 'r', 9: 'h', 10: 'p', 11: 'd', 12: 'j', 13: 'a', 14: 't', 15: 's', 16: 'i', 17: 'v', 18: 'l', 19: 'g', 20: 'u', 21: 'e', 22: 'f', 23: 'k', 24: 'o', 25: 'm', 26: '\n'}

# %% [markdown]
# Functions for random and zero initialization

# %%
def random_init(num_rows, num_cols):
    return np.random.rand(num_rows, num_cols)*0.01

def zero_init(num_rows, num_cols):
    return np.zeros((num_rows, num_cols))

# %% [markdown]
# # RNN MODEL

# %% [markdown]
# **1. Initialization**

# %%
class RNN:
   def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        # hyper parameters
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate
        # model parameters
        self.U = np.random.uniform(-np.sqrt(1./vocab_size), np.sqrt(1./vocab_size), (hidden_size, vocab_size))
        self.V = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (vocab_size, hidden_size))
        self.W = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (hidden_size, hidden_size))
        self.b = np.zeros((hidden_size, 1)) # bias for hidden layer
        self.c = np.zeros((vocab_size, 1)) # bias for output

        # memory vars for adagrad
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        self.mc = np.zeros_like(self.c)

# %% [markdown]
#  It turns out that the best initialization depends on the activation function (tanh in our case) and one recommended approach is to initialize the weights randomly in the interval from [ -1/sqrt(n), 1/sqrt(n)] where n is the number of incoming connections from the previous layer.
#
#  This is called Xavier or Glorot Initialization. The Xavier Initialization method is calculated as a random number with a uniform probability distribution (U) between the range -(1/sqrt(n)) and 1/sqrt(n), where n is the number of inputs to the node.

# %% [markdown]
# Adagrad (Adaptive Gradient Algorithm) is an optimization algorithm used in training neural networks. It adjusts the learning rate for each parameter based on the historical gradients of that parameter.
#
# It is better than SGD and works well for NLP data.

# %% [markdown]
# **2. Forward Pass**

# %% [markdown]
# Softmax Code

# %%
   def softmax(self, x):
        p = np.exp(x- np.max(x))
        return p / np.sum(p)

# %% [markdown]
# Forward Propagation Code

# %%
   def forward(self, inputs, hprev):
            xs, hs, os, ycap = {}, {}, {}, {}
            hs[-1] = np.copy(hprev)
            for t in range(len(inputs)):
                xs[t] = zero_init(self.vocab_size,1)
                xs[t][inputs[t]] = 1 # one hot encoding , 1-of-k
                hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
                os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
                ycap[t] = self.softmax(os[t]) # probs for next char
            return xs, hs, ycap

# %% [markdown]
# Follows the below equations-
#
# a(t) = b + W*h(t-1) + U*x(t)
#
# h(t) = tanh(a(t))
#
# o(t) = c + V*h(t)
#
# y(t)= softmax(o(t))

# %% [markdown]
# **3. Compute Loss**

# %%
   def loss(self, ps, targets):
            # calculate cross-entropy loss
            return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length))

# %% [markdown]
# Cross-entropy Loss is the Loss function used and is used to train the network with respect to the words that are outputted by the network. In multi-class classification we take the sum of log loss values for each class prediction in the observation
#
# The most important thing to remember is that the Y vector will only be 1 at the correct class and 0 everywhere else. The intent is the increase the probability of the correct class, and to decrease the probabilities of the rival classes.

# %% [markdown]
# **4. Backward Pass**

# %%
   def backward(self, xs, hs, ps, targets):
            # backward pass: compute gradients going backwards
            dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
            db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
            dhnext = np.zeros_like(hs[0])
            for t in reversed(range(self.seq_length)):
                dy = np.copy(ps[t])
                #through softmax
                dy[targets[t]] -= 1 # backprop into y
                #calculate dV, dc
                dV += np.dot(dy, hs[t].T)
                dc += dc
                #dh includes gradient from two sides, next cell and current output
                dh = np.dot(self.V.T, dy) + dhnext # backprop into h
                # backprop through tanh non-linearity
                dhrec = (1 - hs[t] * hs[t]) * dh  #dhrec is the term used in many equations
                db += dhrec
                #calculate dU and dW
                dU += np.dot(dhrec, xs[t].T)
                dW += np.dot(dhrec, hs[t-1].T)
                #pass the gradient from next cell to the next iteration.
                dhnext = np.dot(self.W.T, dhrec)
            # clip to mitigate exploding gradients
            for dparam in [dU, dW, dV, db, dc]:
                np.clip(dparam, -5, 5, out=dparam)
            return dU, dW, dV, db, dc

# %% [markdown]
# Gradient clipping is done to prevent gradient explosion. It involves modifying the gradients during training so that they do not exceed a predefined threshold. If the gradient of a parameter exceeds this threshold, it is scaled down proportionally to ensure that its magnitude remains within a reasonable range.
#
# Whereas the exploding gradient can be fixed with gradient clipping technique as is used in the example code here, the vanishing gradient issue is still is major concern with an RNN. Hence, LSTM, GRU, ResNets are better solutions for NLP tasks and can avoid vanishing gradient.

# %% [markdown]
# **5. Update Weights**

# %%
   def update_model(self, dU, dW, dV, db, dc):
        # parameter update with adagrad
        for param, dparam, mem in zip([self.U, self.W, self.V, self.b, self.c],
                                  [dU, dW, dV, db, dc],
                                  [self.mU, self.mW, self.mV, self.mb, self.mc]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem+1e-8) # adagrad update

# %% [markdown]
# **6. Sampling**

# %%
   def sample(self, h, seed_ix, n):
    ixes = []
    for _ in range(n):
        x = np.zeros((self.vocab_size, 1))
        x[seed_ix] = 1
        h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
        y = np.dot(self.V, h) + self.c
        p = np.exp(y - np.max(y)) / np.sum(np.exp(y - np.max(y)))
        ix = np.random.choice(range(self.vocab_size), p=p.ravel())
        seed_ix = ix  # Update seed_ix for the next iteration
        ixes.append(ix)
    return ixes

# %% [markdown]
# Once the RNN is trained, the sample function allows you to generate new sequences of text by iteratively predicting the next character based on the previous characters. This is useful for tasks like generating creative text, composing music, or generating code.
#
# The sample method generates a sequence of integers from the model by iteratively predicting the next character based on the current state and sampling from the output distribution. It utilizes one-hot encoding to represent characters, ensuring compatibility with the model architecture.

# %% [markdown]
# **7. Train model**

# %%
   def train(self, data):
    # Initialize variables
    iter_num = 0
    threshold = 0.1

    # Training loop
    while True:  # Keep iterating until explicitly broken
        # Initialize hidden state
        hprev = np.zeros((self.hidden_size, 1))

        # Generate random starting point for input sequence
        start_idx = np.random.randint(0, data_size - self.seq_length)
        inputs = [char_to_ix[ch] for ch in data[start_idx:start_idx + self.seq_length]]
        targets = [char_to_ix[ch] for ch in data[start_idx + 1:start_idx + self.seq_length + 1]]

        # Forward pass
        xs, hs, ps = self.forward(inputs, hprev)
        # Backward pass
        dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
        # Compute loss
        loss = self.loss(ps, targets)
        # Update model parameters
        self.update_model(dU, dW, dV, db, dc)
        # Update hidden state
        hprev = hs[self.seq_length - 1]

        # Print progress occasionally
        if not iter_num % 500:
            sample_ix = self.sample(hprev, inputs[0], 200)
            print(''.join(ix_to_char[ix] for ix in sample_ix))
            print("iter: %d, loss: %f" % (iter_num, loss))

        # Check if loss is below threshold, if so, break the loop
        if loss < threshold:
            break

        iter_num += 1

# %%
import numpy as np

class RNN:
    def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        # Initialize parameters
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate

        # Initialize model parameters
        self.U = np.random.uniform(-np.sqrt(1./vocab_size), np.sqrt(1./vocab_size), (hidden_size, vocab_size))
        self.V = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (vocab_size, hidden_size))
        self.W = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (hidden_size, hidden_size))
        self.b = np.zeros((hidden_size, 1)) # bias for hidden layer
        self.c = np.zeros((vocab_size, 1)) # bias for output

        # memory vars for adagrad
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        self.mc = np.zeros_like(self.c)

    def softmax(self, x):
        p = np.exp(x - np.max(x))
        return p / np.sum(p)

    def forward(self, inputs, hprev):
        xs, hs, os, ycap = {}, {}, {}, {}
        hs[-1] = np.copy(hprev)
        for t in range(len(inputs)):
            xs[t] = np.zeros((self.vocab_size, 1))
            xs[t][inputs[t]] = 1 # one hot encoding, 1-of-k
            hs[t] = np.tanh(np.dot(self.U, xs[t]) + np.dot(self.W, hs[t-1]) + self.b) # hidden state
            os[t] = np.dot(self.V, hs[t]) + self.c # unnormalized log probs for next char
            ycap[t] = self.softmax(os[t]) # probs for next char
        return xs, hs, ycap

    def loss(self, ps, targets):
        # calculate cross-entropy loss
        return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length))

    def backward(self, xs, hs, ps, targets):
        # backward pass: compute gradients going backwards
        dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
        db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
        dhnext = np.zeros_like(hs[0])
        for t in reversed(range(self.seq_length)):
            dy = np.copy(ps[t])
            # through softmax
            dy[targets[t]] -= 1 # backprop into y
            # calculate dV, dc
            dV += np.dot(dy, hs[t].T)
            dc += dc
            # dh includes gradient from two sides, next cell and current output
            dh = np.dot(self.V.T, dy) + dhnext # backprop into h
            # backprop through tanh non-linearity
            dhrec = (1 - hs[t] * hs[t]) * dh  # dhrec is the term used in many equations
            db += dhrec
            # calculate dU and dW
            dU += np.dot(dhrec, xs[t].T)
            dW += np.dot(dhrec, hs[t-1].T)
            # pass the gradient from next cell to the next iteration.
            dhnext = np.dot(self.W.T, dhrec)
        # clip to mitigate exploding gradients
        for dparam in [dU, dW, dV, db, dc]:
            np.clip(dparam, -5, 5, out=dparam)
        return dU, dW, dV, db, dc

    def update_model(self, dU, dW, dV, db, dc):
        # parameter update with adagrad
        for param, dparam, mem in zip([self.U, self.W, self.V, self.b, self.c],
                                  [dU, dW, dV, db, dc],
                                  [self.mU, self.mW, self.mV, self.mb, self.mc]):
            mem += dparam * dparam
            param += -self.learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

    def sample(self, h, seed_ix, n):
        ixes = []
        for _ in range(n):
            x = np.zeros((self.vocab_size, 1))
            x[seed_ix] = 1
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            p = np.exp(y - np.max(y)) / np.sum(np.exp(y - np.max(y)))
            ix = np.random.choice(range(self.vocab_size), p=p.ravel())
            seed_ix = ix  # Update seed_ix for the next iteration
            ixes.append(ix)
        return ixes

    def train(self, data):
     # Initialize variables
     iter_num = 0
     threshold = 0.1

     # Training loop
     while True:  # Keep iterating until explicitly broken
        # Initialize hidden state
        hprev = np.zeros((self.hidden_size, 1))

        # Generate random starting point for input sequence
        start_idx = np.random.randint(0, data_size - self.seq_length)
        inputs = [char_to_ix[ch] for ch in data[start_idx:start_idx + self.seq_length]]
        targets = [char_to_ix[ch] for ch in data[start_idx + 1:start_idx + self.seq_length + 1]]

        # Forward pass
        xs, hs, ps = self.forward(inputs, hprev)
        # Backward pass
        dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
        # Compute loss
        loss = self.loss(ps, targets)
        # Update model parameters
        self.update_model(dU, dW, dV, db, dc)
        # Update hidden state
        hprev = hs[self.seq_length - 1]

        # Print progress occasionally
        if not iter_num % 500:
            sample_ix = self.sample(hprev, inputs[0], 200)
            print(''.join(ix_to_char[ix] for ix in sample_ix))
            print("iter: %d, loss: %f" % (iter_num, loss))

        # Check if loss is below threshold, if so, break the loop
        if loss < threshold:
            break

        iter_num += 1

# %%
seq_length = 6
rnn = RNN(hidden_size=100, vocab_size=vocab_size, seq_length=seq_length, learning_rate=1e-1)
rnn.train(filtered_data)
# Out:
# Streaming output truncated to the last 5000 lines.
# einn
# donam
# trique
# brien
# licki
# myrah
# paula
# nickitly
# rashina
# pedriamaya
# machanda
# juyton
# chancin
# jomia
# darinnettaci
# dannoe
# sharyn
# julie
# wilton
# vinesterine
# dania
# shyl
# rake
# chegd
# nasmanc
# joram
# lavenn
# quinn
# iter: 440000, loss: 10.396380
# lix
# andree
# naroa
# vincia
# ginra
# leolie
# rixa
# netela
# yergin
# francis
# kara
# kadell
# kaitre
# karl
# joanna
# chardon
# varran
# gabroylen
# garrey
# carlenandie
# jeann
# floakes
# dallo
# shelton
# stivea
# sheyne
# aubrin
# icalvie
# jees
# iter: 440500, loss: 9.699934
# t
# kelisa
# leonna
# eflen
# cectionst
# annela
# luciosa
# sudni
# candido
# haige
# shanselt
# shar
# eovanne
# lete
# sezeman
# elane
# merathanett
# coresa
# laurnie
# andre
# kristile
# albert
# mellenne
# trell
# german
# sabel
# genekie
# lauron
#
# iter: 441000, loss: 9.496154
# johusson
# comathene
# jedie
# marith
# liza
# timea
# kindoprinna
# danall
# fredon
# car
# dana
# betther
# maxus
# alda
# sereston
# nanay
# marrotnen
# marqakr
# tralinite
# cathlynne
# quint
# mallina
# rob
# demee
# jahoyla
# melina
# gettel
# alli
# iter: 441500, loss: 7.580268
# lalo
# rayan
# shaela
# ascharna
# tyzaldra
# dadales
# dewnalyp
# robry
# kames
# ariea
# maklyn
# rosetyania
# aley
# alichalfyan
# huyd
# corry
# dangelyn
# elean
# reeven
# jamiel
# brahrin
# louban
# laire
# vivian
# clarn
# cacrin
# viul
# emissild
# iter: 442000, loss: 11.206044
# sh
# lyn
# frede
# kelly
# kimie
# ela
# dila
# kristip
# rosa
# marthe
# reyo
# garry
# sonnahany
# leanna
# yara
# danna
# lana
# reben
# lorron
# marcilge
# tessee
# s
# ellen
# lane
# lorot
# hurt
# adrie
# alyne
# charlod
# jasera
# jatie
# clek
# julia
# kra
# s
# iter: 442500, loss: 8.310593
#
# christipe
# billyn
# maismy
# racissa
# tarra
# luil
# darna
# ginnertan
# caroli
# makcicha
# lviele
# jenal
# kience
# chela
# jennaul
# roya
# luciet
# gavank
# mitusty
# teroy
# dobbie
# riley
# cammy
# marima
# adrian
# beltreymo
# fatr
# jay
# dolag
# iter: 443000, loss: 10.627773
# e
# hanna
# cobika
# lien
# kyne
# codnle
# dana
# lorda
# lucki
# brancis
# gaanioh
# keris
# maken
# jonia
# lena
# geith
# roby
# adi
# charlesia
# malius
# fohjaunie
# edwi
# ruthbalyon
# tricie
# slynie
# ma
# timmie
# adai
# mackey
# samay
# aadi
# latasse
# iter: 443500, loss: 9.492622
# i
# thara
# rosen
# aviret
# gian
# lat
# loren
# maron
# rayver
# triy
# sudei
# manier
# hadita
# paillenie
# michorene
# sardon
# leonatta
# patt
# geisha
# nott
# deannetta
# rodarra
# frandie
# deeigue
# rothiald
# marsassi
# ermae
# evonne
# launel
# g
# iter: 444000, loss: 10.622239
# rinee
# teflin
# staph
# fretta
# gristin
# ollanee
# fernie
# bel
# madesty
# gerthacy
# leoscharel
# wary
# clathiohara
# ther
# loorah
# janela
# marisephane
# alvas
# lequelie
# allina
# johe
# kalley
# makelme
# robert
# ernand
# erika
# alimond
# b
# iter: 444500, loss: 13.895038
# evan
# sude
# jernellia
# nasther
# minique
# marsan
# suzy
# chloy
# rewna
# tholl
# roddord
# alana
# delin
# ely
# ahmova
# marians
# evanna
# catom
# ange
# aakie
# lillian
# ervinard
# argerick
# aratsia
# claminecine
# torze
# jackie
# nicendo
# berr
# iter: 445000, loss: 17.778847
# ackey
# ctarl
# melva
# aualey
# kinziferchon
# jace
# liuon
# rachowne
# lacitley
# edfie
# adelica
# ladyep
# raspal
# rette
# corett
# joheline
# byltar
# tobvin
# lmany
# kayl
# herema
# casemma
# josha
# trey
# michen
# marisa
# marisan
# jown
# ywin
#
# iter: 445500, loss: 9.644724
# edwifa
# shanie
# mike
# halton
# troae
# kulette
# deslizan
# diizab
# jaseil
# wilfrey
# arlez
# shallin
# gindad
# rushell
# iliah
# bradciss
# elaca
# freetr
# cherisy
# sonique
# jefferard
# royel
# alife
# wilaura
# kurtie
# ranseo
# elexa
# nicmyn
# iter: 446000, loss: 9.202247
# na
# jericole
# avoe
# jean
# landon
# dianer
# jane
# carsy
# jalela
# saine
# jisa
# darlei
# joysna
# jufus
# aphan
# quillien
# lucia
# aagh
# shaw
# shanna
# sardin
# alina
# shean
# rexindo
# darrie
# bela
# iana
# abreen
# rewna
# jodin
# tobbia
# judia
# e
# iter: 446500, loss: 14.820251
# cy
# navalumeh
# armon
# deitace
# lalessia
# muett
# blidiley
# tamzay
# shaosesce
# corlee
# elieda
# rostian
# laary
# bovannin
# ernoli
# patty
# devin
# jatophe
# jeary
# danikasis
# tyder
# eomiel
# heda
# davey
# vari
# gia
# keeana
# falen
# tydell
# iter: 447000, loss: 8.287539
#
# amethy
# tam
# louden
# geydo
# brad
# samuselyn
# guado
# dylley
# franlia
# hoya
# braith
# jay
# beth
# helson
# deell
# mary
# tazath
# myorune
# melora
# kriston
# joa
# monita
# denna
# kalie
# rexirgon
# amber
# gerttuf
# breddin
# emmie
# simanne
# ad
# iter: 447500, loss: 13.966934
# l
# patry
# colez
# gareyno
# daifradey
# jorudo
# john
# romian
# akat
# marcall
# glel
# nichen
# etya
# kate
# alter
# frey
# arma
# oue
# jeanne
# rosele
# naul
# hemalison
# guen
# yoicke
# esha
# ruby
# omeas
# anaro
# shauleli
# zovon
# shller
# zarlyn
# ja
# iter: 448000, loss: 12.092779
# y
# emmyne
# lula
# wendie
# jennifarttel
# anghory
# wilbesla
# lann
# leyan
# shelbin
# bellyn
# elianaral
# shef
# mauryn
# kayla
# anthurett
# carlar
# isabra
# rachella
# mariah
# hila
# ramanda
# sheelnk
# elias
# brynn
# lynne
# marla
# claudie
# lo
# iter: 448500, loss: 7.906321
# anat
# berbie
# adrian
# tamay
# dovon
# vilsa
# chrry
# jadebena
# tarahne
# alichona
# lorelely
# quella
# tama
# welton
# hustes
# patrick
# jayley
# tofyona
# marigur
# marine
# mika
# helbert
# solandrry
# ourdet
# mabey
# hoy
# pabrie
# jany
# fannie
# iter: 449000, loss: 9.679601
#
# mari
# sababeris
# frankisto
# candra
# haeber
# villara
# pauik
# tlevin
# stuphavin
# elia
# alberti
# vivorden
# verron
# javoin
# bua
# ashley
# lendie
# christine
# vine
# samiersa
# manja
# willie
# elven
# pynaron
# merin
# charly
# tarel
# anna
#
# iter: 449500, loss: 10.835825
# ray
# myrisa
# lene
# martha
# dondol
# nelanda
# pabret
# darry
# shavine
# jaane
# aycon
# wante
# emichaelan
# daverin
# yobie
# fredris
# helexalh
# marave
# jeannefflein
# arth
# caris
# grich
# colline
# robethai
# jeselia
# jimey
# lauret
# hulus
#
# iter: 450000, loss: 11.636383
# r
# julian
# lie
# sangelyn
# lainojosa
# jadle
# treeth
# isia
# carmen
# dauden
# janah
# micharlanda
# katherio
# mina
# linda
# belanina
# mariquis
# uzia
# kenthalina
# apristiph
# lauiso
# maxrie
# chyneth
# dworyn
# lendy
# sondy
# momeria
# kulli
# iter: 450500, loss: 11.927136
# aliston
# rosharrel
# estel
# noe
# ezne
# adrie
# alwy
# corine
# mayder
# odson
# fronelynto
# thovie
# shlonton
# stejubie
# milayla
# ckrence
# carlon
# jacis
# loone
# leenne
# katari
# sheven
# bwian
# mictarie
# adeli
# greth
# garah
# jennerie
# br
# iter: 451000, loss: 10.101194
# hon
# trest
# killorso
# terry
# victo
# abra
# jeffry
# tonny
# brista
# cherry
# zoriel
# erica
# martob
# jamer
# sseres
# martin
# hathy
# nana
# dashery
# issa
# masina
# gabby
# javmen
# denson
# corista
# sidney
# anatana
# sonia
# breanne
# andia
# bre
# iter: 451500, loss: 12.622224
# laren
# shannerine
# lulennah
# carma
# mynta
# johandra
# teron
# kitebe
# leith
# paina
# lila
# maurino
# roany
# niam
# kaydrian
# patal
# terrilly
# macelina
# monaliah
# coristin
# ahlist
# delereo
# rachell
# glom
# cilie
# kaysh
# albertl
# halle
# iter: 452000, loss: 9.042285
# oland
# erriellee
# jencelene
# joanna
# dilof
# jolon
# tamyr
# aarotte
# nately
# fashley
# charlor
# jameble
# shallyn
# wilfrenca
# lindreg
# giel
# hana
# isaerick
# anda
# llisci
# anastalle
# carlent
# josevanne
# leony
# soniarno
# ashalle
# co
# iter: 452500, loss: 8.942158
#
# lianne
# chelly
# diake
# khile
# dolb
# toriyd
# benitmae
# jaceb
# rick
# lucie
# jimmy
# mauelynre
# laney
# rachellce
# jaskan
# logeris
# marah
# jeanna
# devata
# sela
# andold
# frank
# shannel
# ron
# julley
# aubelle
# trickise
# rosa
# rylorit
# p
# iter: 453000, loss: 14.362130
# cathon
# sidta
# ailerio
# collane
# joaele
# biiban
# evila
# rilvin
# derigebie
# shelena
# mylei
# louissa
# mammion
# chrulina
# scissene
# rabioney
# cwitha
# hayemisabela
# anahar
# hayelixa
# zarralee
# fredel
# helby
# culena
# irane
# bebnys
# iter: 453500, loss: 13.055176
# allin
# delline
# ellisthey
# anars
# mouric
# duly
# jadene
# huestah
# marice
# mand
# ellin
# geriellor
# brennysem
# ter
# lendan
# cldred
# tuller
# prichi
# hutter
# janie
# gina
# bradi
# lico
# ymolicorlo
# micia
# remi
# ronnie
# corry
# steney
# ry
# iter: 454000, loss: 12.890381
# a
# lenje
# loadrey
# kaylm
# hoel
# cley
# soncelyn
# ray
# jodi
# savany
# ros
# jean
# sharanson
# rubel
# cartie
# kaiqua
# leweag
# bevonnie
# mcerta
# lory
# maxvin
# pett
# resiler
# aloya
# tardyn
# julisaa
# marivaje
# cicoven
# nesenadon
# jackane
#
# iter: 454500, loss: 9.975571
# arley
# bobbyn
# kaiby
# lissa
# kart
# hacquell
# yylerico
# elizack
# marthely
# dalley
# josie
# joannan
# sabir
# bettell
# damer
# laure
# terra
# jassandela
# barel
# derto
# haylene
# jessy
# aulen
# makelly
# bryjouma
# mamly
# sharler
# sandrey
#
# iter: 455000, loss: 12.118320
# anfon
# locath
# elina
# natherie
# danlee
# daxlyn
# elmie
# vivia
# mandan
# chrisian
# chrestina
# brutz
# tobant
# olivell
# nikaliana
# deandred
# royka
# evon
# jazisha
# gebnairie
# lucyd
# ydaven
# bebel
# jiffan
# karian
# gonnssa
# ballin
# fes
# iter: 455500, loss: 11.295650
# line
# noemine
# don
# matty
# krisy
# safaha
# loidricticia
# carlie
# neen
# somina
# kauk
# storly
# christaci
# johna
# alina
# jimikley
# delley
# aslica
# mariannica
# nake
# skelli
# mattherah
# mark
# julita
# dapherine
# edrian
# moldia
# lonie
#
# iter: 456000, loss: 11.048666
# a
# naisher
# jemt
# tevary
# filfrickis
# odite
# kall
# rona
# brancos
# alfold
# bridgert
# wrodi
# dianori
# tonia
# jeannie
# raylor
# willian
# staylet
# recinritlel
# ann
# moranda
# brynthrick
# hendie
# merandra
# yanard
# deroce
# garbert
# she
# iter: 456500, loss: 10.211760
# l
# anger
# nok
# raspera
# donardon
# gwency
# saber
# steph
# nadnietta
# briannochae
# alore
# mauric
# dendia
# estroe
# lindrey
# shanna
# marsamango
# oltigh
# yar
# sagho
# annia
# donort
# antin
# kenlyn
# kiestall
# jarebera
# nena
# husten
# nath
# iter: 457000, loss: 16.359207
# el
# hela
# dosora
# ciso
# luky
# maresticy
# kally
# lou
# sulan
# isaai
# joden
# shawnne
# fradolyn
# arnestie
# allis
# jennifoe
# caristye
# zosca
# betthel
# doblie
# chrejana
# korrie
# morgan
# shel
# clayron
# shelai
# edeliana
# kendrey
# earthe
# iter: 457500, loss: 11.576799
# ie
# tearria
# sandarsa
# jacki
# jomin
# troncell
# ariane
# hoston
# jossuella
# eume
# guene
# genna
# shanna
# angenia
# lociell
# dereli
# perly
# rella
# tristin
# evan
# clady
# kerann
# nathan
# dary
# adelia
# benarmanne
# kenna
# jamis
# halaya
# j
# iter: 458000, loss: 11.282422
# rimi
# ierman
# guney
# julea
# deith
# erina
# candrey
# shophern
# narmen
# adgence
# marette
# pensse
# kennant
# pristie
# gisharlay
# ronna
# steph
# lanis
# annetry
# velelyn
# alishry
# sampen
# josa
# greni
# marlen
# chenden
# zachain
# marcion
#
# iter: 458500, loss: 12.440560
# e
# dania
# arlea
# rylae
# elinte
# leerdie
# houstine
# colina
# iga
# bulley
# leonna
# charleny
# julie
# chris
# dyan
# frank
# secelisa
# brise
# koline
# dork
# makelissa
# chrmyn
# coyem
# heugon
# wilbell
# laurence
# priska
# antou
# ran
# cosee
# kr
# iter: 459000, loss: 9.403907
# ony
# alexsepha
# cearleiwh
# aucah
# berni
# tha
# kerrin
# lamerine
# joas
# gina
# eliwonelian
# fannie
# deseda
# josie
# mantian
# evele
# donissa
# roxam
# hana
# cherob
# jaidee
# andrey
# alvan
# vanise
# madia
# justin
# sharila
# adeliase
# belun
# iter: 459500, loss: 10.400946
#
# lousince
# mansesta
# katel
# mxison
# carla
# davin
# triscei
# jamen
# janabel
# auana
# cacrie
# freber
# vinton
# jorisma
# patty
# wille
# tima
# kina
# ziany
# caro
# ekinare
# rennip
# jonprah
# gay
# juys
# maudrenzie
# camela
# relber
# jean
# dolt
# iter: 460000, loss: 10.162999
#
# ravon
# koarin
# tharya
# keira
# witte
# kianuy
# kelee
# trequinoy
# kerroth
# rosmyn
# isiah
# leonar
# shy
# morgan
# lafrand
# beta
# marianna
# ashlyn
# annet
# darian
# emakwerd
# meye
# julil
# pendon
# shawnold
# sheron
# roley
# jeanie
# cine
# kr
# iter: 460500, loss: 13.254407
# bie
# carvin
# samma
# malliel
# isarandil
# bladiesien
# jeffan
# cinlenco
# mogtin
# doshor
# lawal
# clace
# lorene
# derrin
# andrissa
# ceral
# jame
# vont
# lenney
# daelen
# wastisioya
# lay
# pegri
# cashlay
#
# rone
# willa
# aubenya
# alicoa
# jan
# iter: 461000, loss: 10.807819
#
# giol
# nathi
# pattina
# charelle
# doryen
# kilirousrissie
# penna
# jacian
# delloriel
# elitone
# elda
# echarlo
# peleyda
# tanys
# amy
# tond
# robey
# requel
# atthilicemy
# anthalyn
# ruseli
# sophii
# vony
# michul
# oni
# ray
# randald
# elica
#
# iter: 461500, loss: 15.507452
# guiroo
# audra
# sida
# marya
# tayler
# ellia
# emil
# adrylenn
# jimb
# erie
# darlo
# elve
# bertie
# rynessic
# berto
# havie
# deanne
# kalinon
# jawiny
# annnita
# shunice
# jessece
# candin
# koly
# josald
# kajie
# boney
# aineph
# versond
# herry
# jo
# iter: 462000, loss: 9.438541
# allene
# frandino
# ellena
# chigene
# roskila
# jusee
# thelbiatte
# mik
# kayleyme
# maddian
# caron
# sharyn
# michophy
# edkich
# debelleric
# walissepa
# mari
# marty
# racheld
# nue
# fernane
# sonnya
# rayvon
# catleydettan
# john
# ryvio
# mari
# iter: 462500, loss: 9.618898
# ona
# amela
# liune
# danina
# karar
# jake
# patella
# charley
# brectlet
# alony
# parton
# regor
# lorosm
# gearlis
# davo
# stahle
# riana
# ebellan
# pixan
# jayler
# kathlee
# dieanice
# edisa
# adaberla
# kathlynncelo
# etry
# treva
# mastophanny
#
# iter: 463000, loss: 9.319104
# imetti
# mecil
# sald
# robby
# saul
# oven
# anniquis
# kiano
# deginia
# degriasa
# bennya
# nazmal
# rubent
# geith
# rayna
# manuilat
# elnica
# ierrettran
# willie
# melixiale
# malise
# patersop
# chawisty
# lucer
# caron
# carley
# albilyn
# barle
# iter: 463500, loss: 10.998377
# s
# gepra
# muld
# alice
# clack
# ernard
# kotiadele
# kardriela
# lauria
# azacalma
# makterine
# shanaut
# belvoe
# emman
# aphie
# risa
# rison
# rauesisia
# diesced
# bornald
# chriet
# eliss
# chamil
# angelyson
# rulth
# scelica
# lauresa
# justin
# iter: 464000, loss: 11.487017
# en
# rodd
# avin
# xais
# wenda
# eldsea
# shertyn
# wilfradulenn
# kemis
# ette
# leenorel
# esha
# mynet
# laurick
# byllorin
# mechomer
# heleneilis
# tailian
# lesson
# anara
# marciss
# sherle
# sheri
# myron
# filurer
# kiyvy
# jamia
# anyel
# aagett
# iter: 464500, loss: 13.397273
# ennathannea
# eltalie
# ranah
# tonie
# dara
# williell
# aleana
# arlyn
# sadmin
# elica
# alemie
# dayron
# cherri
# broy
# lillicigei
# verna
# kataby
# buanny
# franderna
# bron
# dory
# jodyvan
# darancoon
# jonnory
# riman
# anarecianna
# maxan
# m
# iter: 465000, loss: 10.445094
# levin
# rasya
# leonda
# londo
# gaoly
# banny
# kasey
# wakcian
# wesvie
# callenzonberlo
# rogurumsta
# lebyani
# adelin
# lenick
# frannely
# fost
# onerie
# fannelan
# josalin
# benna
# soran
# brede
# liovan
# darie
# lendrica
# hea
# kayla
# joses
#
# iter: 465500, loss: 9.880881
# len
# ra
# benda
# evad
# gailyn
# matrian
# jaxa
# les
# madiela
# rogelyn
# patrice
# conton
# judio
# selene
# jora
# pattri
# awiliame
# aaniya
# yshany
# jace
# lbiel
# wwyna
# sandred
# albencie
# eazo
# patton
# nier
# carlyn
# jessinex
# alene
# benn
# r
# iter: 466000, loss: 11.718912
# lahara
# reonne
# tacharito
# cinah
# camant
# borrock
# beric
# aerrey
# elaaca
# ryomma
# tirga
# elvie
# erel
# chell
# rttie
# rigira
# tammy
# rachacy
# vuctord
# arges
# jeri
# tamiela
# evale
# hacky
# gaitany
# regerton
# cylten
# sara
# artaley
# gr
# iter: 466500, loss: 12.989385
# e
# anell
# roblie
# jelina
# emmando
# annen
# phaneth
# tha
# kenni
# farrely
# miudy
# brity
# fonnie
# simua
# davy
# jonald
# tory
# masan
# jakia
# aliciases
# miann
# queth
# marce
# elina
# liz
# denicah
# fleene
# harryst
# clersa
# destina
# cacel
# ke
# iter: 467000, loss: 8.974713
# slyn
# clarencie
# jaa
# bephethie
# tacoly
# aleserlyn
# jelmig
# adriczo
# christon
# willie
# waela
# par
# brendaley
# epeline
# kelse
# antoris
# hritsya
# rogele
# gryn
# ophilaney
# crude
# eliadara
# stab
# casima
# yulista
# relsa
# tarhyan
# an
# iter: 467500, loss: 13.963043
# viam
# dont
# virebia
# josen
# detigh
# rejowilse
# makier
# dami
# kallied
# carlyn
# ellestua
# kavin
# donte
# kriston
# cassandell
# ugedelahia
# makeline
# waginisy
# perry
# lusan
# darl
# heldie
# lina
# alder
# alita
# fershnett
# robyi
# angela
# iter: 468000, loss: 12.135457
#
# tyley
# naroile
# celisa
# emmey
# cent
# kerly
# ederis
# charlyn
# jeanner
# josie
# ejrandiebar
# rosphell
# eogala
# dauk
# josaman
# kellia
# tahar
# jeshie
# kela
# fenny
# raycy
# dianna
# lyor
# jeanney
# leifany
# brianna
# kelin
# bernas
# tiurl
# iter: 468500, loss: 8.552348
#
# laudrie
# jerte
# marlir
# brict
# herober
# vinarena
# maryan
# mariel
# no
# fradel
# helessephenifarissa
# freahon
# walthy
# kaysa
# iracia
# abbianna
# larah
# ske
# ricky
# kale
# erisha
# tarriele
# will
# charla
# lee
# uson
# jerrelco
# olam
# re
# iter: 469000, loss: 13.392017
# er
# liana
# betty
# kamero
# alebyn
# kwydork
# stia
# iteamond
# gryn
# eon
# tlimsen
# micked
# mallie
# belore
# andrencent
# robes
# arezardy
# devosta
# shardlian
# yarton
# gesson
# madiel
# regan
# stavie
# norayley
# flanky
# shallor
# jeloffe
# v
# iter: 469500, loss: 14.537702
# mmee
# jena
# hanios
# berby
# dovanea
# ipenie
# jacquell
# tamecharia
# kerri
# theralda
# jordan
# roderecia
# terrie
# shearie
# giole
# madela
# derick
# cardun
# chera
# jiannie
# willie
# pavensephan
# garetlio
# andy
# nike
# patty
# jeryn
# bren
# iter: 470000, loss: 14.241980
# ne
# peitan
# dobie
# bergine
# huy
# tynella
# vivedelle
# carold
# jordy
# geamina
# chary
# michalla
# mel
# nisk
# ette
# brayles
# maxie
# lacitta
# ciefan
# amke
# guusha
# dardele
# rosique
# tohine
# abbia
# chroa
# milla
# glekane
# pathan
# tamay
# z
# iter: 470500, loss: 13.721837
#
# braadobon
# emian
# ema
# michelle
# evellyn
# torillo
# fradylo
# bloey
# aodes
# grif
# adoline
# sond
# jimmy
# fponicy
# artor
# carina
# loudra
# davane
# malle
# polyn
# fron
# brend
# liane
# jement
# mill
# dannel
# sesanne
# forgia
# scea
# annassh
# iter: 471000, loss: 9.895270
# i
# brydabettin
# adiema
# kamerlet
# son
# tinie
# jales
# lacey
# lenton
# tomet
# amane
# etha
# hadile
# samari
# lizeun
# jerryce
# daminjorina
# keilyna
# clarely
# raqueley
# vinema
# tammia
# rlyn
# sheleyl
# nicolel
# notren
# marilo
# eleila
# ma
# iter: 471500, loss: 11.108238
# red
# irane
# eloupial
# arne
# cownolly
# beltin
# anadel
# antery
# leace
# comise
# jaikione
# maxk
# joyrendy
# dwonda
# jan
# shilly
# linda
# jacklya
# krissie
# kaice
# leoana
# iana
# anhrew
# alix
# darrie
# shainya
# daik
# davin
# caris
# micharli
# iter: 472000, loss: 9.866705
#
# ezian
# maria
# rob
# marton
# shanley
# keanna
# amily
# neos
# elina
# milge
# jeanne
# icarie
# meroen
# makothy
# marina
# shaney
# villes
# madra
# mancy
# mickinay
# casel
# rose
# carion
# koly
# lon
# tiona
# clare
# johinat
# leonna
# jack
# elma
# cai
# iter: 472500, loss: 13.103871
# a
# henda
# tren
# mitanthell
# harlyn
# raspout
# pau
# ncamencestc
# elaca
# nalea
# dau
# tie
# brissa
# kerry
# banrice
# elta
# kilson
# grett
# gabetha
# leoneva
# volle
# lison
# carroe
# gebriel
# stephany
# alma
# toneth
# koiles
# tone
# gaith
# cher
# iter: 473000, loss: 8.730758
# ny
# dovon
# thrynn
# manuel
# raxly
# claido
# salia
# alixah
# luidynury
# keryla
# carley
# aidriana
# stelsa
# lerma
# juan
# bristy
# jeffora
# emokela
# tongin
# terden
# kardin
# alachan
# timamini
# delisla
# rosale
# latrione
# keltance
# karila
# iter: 473500, loss: 10.845330
# garmen
# shau
# tamnie
# gresylley
# corle
# sonett
# mikanebe
# every
# maepe
# caron
# victee
# correy
# sasa
# lageelyn
# ricky
# salys
# jereara
# anitia
# adandacy
# bragritt
# frana
# lucilla
# daniel
# willey
# may
# esten
# elline
# angellee
# phil
# iter: 474000, loss: 13.094467
# nie
# kricendo
# abra
# mangy
# coltonga
# maria
# briana
# delas
# juria
# mirlend
# oloh
# fraddra
# marley
# argarrand
# raeva
# lindy
# lee
# cara
# quina
# leeliea
# saile
# carolyn
# kena
# call
# reann
# ana
# davio
# anjert
# homen
# kairee
# thynna
# ap
# iter: 474500, loss: 10.621161
# rlie
# ary
# joseph
# zien
# steg
# noemine
# nita
# earla
# ednie
# eloe
# trine
# elmin
# dan
# oldeni
# shewrica
# thewann
# katrey
# annet
# garonce
# brige
# oavanna
# timf
# charly
# duand
# joanne
# jest
# angrod
# chnrs
# isa
# marca
# ari
# karolke
# rose
# iter: 475000, loss: 12.042454
# wance
# codish
# rugane
# salva
# lasela
# rayne
# macquizail
# retty
# jaeque
# roxin
# jimmy
# ison
# caelenie
# iugh
# nyah
# madia
# isam
# edann
# dian
# jeron
# josepher
# kenec
# madniel
# jamin
# alma
# janah
# albarl
# clijori
# alicia
# jacquelyn
# a
# iter: 475500, loss: 14.100404
# oline
# cundeavan
# rachenie
# jole
# clinta
# maxia
# vandon
# joshanica
# ishah
# vittani
# angelyna
# esveer
# treyan
# devona
# sulesh
# lerimen
# lara
# sathy
# breagaris
# anto
# jurtinni
# steph
# navanna
# rex
# zena
# dovana
# kara
# nolson
# laur
# iter: 476000, loss: 6.353431
# ra
# charline
# casiren
# aebert
# minna
# alleste
# hentacie
# josmian
# malexie
# chan
# marzon
# jennix
# abbert
# marian
# willy
# athle
# danna
# vase
# terleth
# steven
# jeffes
# mileido
# wustina
# therene
# gwadder
# velley
# pamevie
# alie
# defo
# iter: 476500, loss: 12.808243
# a
# alicia
# lues
# neenton
# frede
# na
# omiana
# frankon
# shiley
# claudoe
# raylon
# gary
# shelene
# jemara
# freanna
# bindyloge
# choroge
# arlamica
# shannah
# ernca
# alexamud
# jammy
# eliale
# giomarr
# zachyn
# sherryd
# allyn
# venacher
# gen
# iter: 477000, loss: 13.748248
# s
# anthallie
# seanne
# shavah
# juan
# randi
# jamivian
# aubie
# pristiph
# kella
# mi
# keyanna
# channa
# nalena
# granden
# michandi
# loron
# aiges
# nuce
# oline
# maroli
# ioshel
# halse
# loi
# anthon
# prrchil
# joy
# shelme
# geandovanni
# hart
# b
# iter: 477500, loss: 10.154087
# arris
# faslin
# cleat
# sion
# leeite
# parget
# idanita
# yoas
# miguben
# wel
# jeannee
# tyrow
# tim
# mallie
# brid
# anghurreo
# larries
# deanita
# isady
# amaynn
# leonard
# molla
# marte
# kenter
# anther
# tarolian
# joanna
# rendar
# elissie
# bet
# iter: 478000, loss: 15.845728
# a
# marilmen
# kers
# carole
# lenadyllo
# destan
# zamary
# zake
# grys
# paurin
# lauges
# americk
# cristof
# jackane
# garenne
# joris
# karrell
# dariel
# jodenna
# angele
# deminici
# arian
# freder
# dolina
# guelis
# reley
# darreke
# eliccestan
#
# iter: 478500, loss: 13.893818
# or
# ellena
# maxice
# patty
# conna
# lariel
# romer
# jascia
# arte
# gren
# keshia
# sharo
# karina
# marlen
# hadalex
# wanter
# karl
# narla
# ronalden
# casty
# jenny
# debordo
# roby
# hodean
# eerrendrie
# delisa
# marim
# ilaon
# christel
# ferek
# le
# iter: 479000, loss: 14.559174
# yrec
# davel
# williania
# hail
# wesuel
# cailly
# shelline
# bertl
# denzimay
# lindon
# corice
# carlina
# milon
# drell
# arid
# dolyn
# rick
# myrise
# kristiada
# hana
# doldre
# joelles
# royno
# marhaia
# lolle
# michul
# glara
# suck
# patrine
# jen
# iter: 479500, loss: 22.106233
# ge
# soefangelia
# maria
# dimerti
# notte
# ram
# irynela
# emmey
# daniclee
# chaylia
# nierie
# jaces
# thicta
# danai
# tyrodyn
# jameste
# stace
# talen
# kristinja
# ellie
# casmora
# arran
# russo
# andlea
# arie
# rarlaet
# cambers
# stedrica
# ann
# iter: 480000, loss: 9.894716
# eris
# marcas
# ami
# jasusin
# iveana
# darlin
# aorian
# ausela
# michaw
# maurre
# shellin
# grodie
# cathy
# sam
# admesakoiz
# willa
# divia
# dexon
# raigna
# scallie
# emmy
# laile
# jackysha
# marian
# ednescer
# hary
# cultorg
# devitt
# marissa
# m
# iter: 480500, loss: 17.463735
# trey
# josephe
# stantela
# christine
# niphray
# sha
# kewariew
# and
# kristine
# joanta
# andra
# marvina
# bethene
# jane
# gebera
# belaa
# kane
# omericabel
# alini
# jess
# clain
# kaley
# shanna
# teaisu
# abise
# carol
# angelly
# era
# kiman
# kare
# iter: 481000, loss: 12.318092
# o
# amelyna
# rucimo
# pryno
# cadra
# cyroli
# jeannel
# urele
# ketheel
# darriane
# kristina
# christe
# alexana
# cald
# sretta
# julipe
# kilda
# lier
# willice
# jeorton
# denitor
# chellian
# frany
# carita
# evera
# mariscia
# ria
# angela
# garta
#
# iter: 481500, loss: 10.060692
# ke
# judia
# velane
# aibal
# ckora
# verwidne
# ara
# spence
# kenna
# marras
# elvin
# aminie
# roxine
# gresten
# niam
# margal
# amalica
# abrie
# scaeleana
# dawal
# herry
# brylliano
# bennie
# kristy
# georgistia
# cemily
# sorius
# horvan
# lua
# lar
# iter: 482000, loss: 11.412578
# er
# amin
# danique
# randelyn
# elextis
# calbor
# trod
# ivan
# claren
# catherina
# patheron
# jaymonda
# chenece
# rosy
# lua
# aupan
# elissa
# bastine
# jory
# maxie
# karine
# lick
# hudi
# ushers
# delsha
# kente
# jena
# kotry
# elto
# ander
# stano
# b
# iter: 482500, loss: 10.945465
# a
# daoda
# lues
# lauan
# chrise
# albie
# joanna
# rucey
# stambela
# alprisa
# kalissa
# leerrene
# kari
# zossel
# paiah
# jastine
# myrilia
# timmy
# peres
# reveal
# iolyn
# prushi
# maria
# nachary
# louiso
# kamie
# marvio
# nichish
# desiva
# branet
# iter: 483000, loss: 23.580837
# luciliughanry
# harm
# rob
# fabra
# eliarie
# sasanterney
# hanrtan
# vickystariala
# teonna
# rugan
# cinda
# artin
# looen
# nilara
# reues
# dalleya
# emily
# kriscillie
# bethara
# tyessia
# nette
# tomy
# jenthe
# liler
# herrien
# briann
# jaosh
# iter: 483500, loss: 15.060021
# l
# kylay
# dan
# efna
# kathl
# miti
# nicha
# stefrel
# jacenne
# dona
# joean
# robbyn
# gradyania
# rya
# thophee
# andy
# all
# malyan
# gindya
# ta
# ani
# denotti
# stentelin
# michie
# latie
# dwary
# kilma
# leugh
# bose
# emisia
# lilyn
# kareliam
# garr
# iter: 484000, loss: 12.332624
# ay
# harresia
# kallie
# jolamin
# erig
# elisha
# rasha
# tunell
# araley
# ruoncel
# gilmenell
# marie
# aleshal
# harrenfer
# ashlesle
# penoren
# clara
# loper
# vanen
# gariana
# laquesse
# alelis
# jahune
# mien
# varnalda
# alas
# daine
# ciana
# ki
# iter: 484500, loss: 14.457499
# ligie
# laisey
# neo
# eloa
# kann
# kenite
# trey
# jaffas
# skence
# tella
# alian
# flodia
# julia
# eleala
# franniely
# tie
# kiraby
# suceysine
# khirryn
# kryshana
# melina
# coster
# chery
# janna
# kellick
# sele
# challe
# scetto
# leon
# lua
# kiana
# iter: 485000, loss: 9.620768
# dre
# tyronda
# madlestu
# leen
# branne
# rabalyston
# prynire
# getrice
# cabittan
# markhen
# jasiest
# listine
# jody
# fronky
# joannabby
# creddrel
# code
# stepas
# troy
# heeare
# lissi
# lownara
# lucian
# mickaylacia
# clarry
# myrim
# alfrey
# iter: 485500, loss: 10.138621
# ensa
# beondriana
# sephen
# fula
# greacholliert
# hoko
# erbine
# evon
# karlyanth
# noah
# son
# bhieliza
# lowin
# alifo
# ryllea
# kaytue
# prick
# gini
# deraben
# gersand
# kenny
# seenn
# kara
# eshendo
# terbert
# forrie
# denna
# terrilet
# anic
#
# iter: 486000, loss: 11.114625
# ette
# mark
# jazen
# warine
# jannela
# nela
# tiffetharin
# soshir
# gerasse
# quan
# neyven
# conna
# leon
# tib
# tamin
# kaura
# eubent
# bred
# krisa
# freonny
# jame
# ladia
# vera
# tara
# satherre
# alexandre
# aigmen
# bobke
# jerie
# caician
# jery
#
# iter: 486500, loss: 10.211292
# ron
# karbir
# minia
# correlbar
# eeenne
# zalsher
# juregg
# ronie
# remicia
# jania
# jenatherly
# paulon
# carolyn
# julie
# frado
# frandie
# vane
# miltat
# hevery
# williadtin
# erward
# rugus
# iaomad
# avan
# jucistice
# costin
# bernan
# margos
# iter: 487000, loss: 9.754493
# imcey
# kristacte
# hendice
# clairence
# skielorgenier
# sherry
# josann
# adebialee
# keven
# ahrie
# jovey
# shawn
# geadriell
# orynne
# vart
# vamellevan
# stephanne
# lorebecevi
# jonal
# elann
# laurette
# jah
# thereann
# victorina
# henore
# iter: 487500, loss: 11.783583
# hes
# gerya
# kessa
# jertie
# jamas
# bloailysa
# arestane
# zarria
# seemisia
# angie
# arnon
# vickis
# paila
# jae
# dorbie
# jay
# eguan
# kenne
# enry
# sugah
# jud
# paiton
# aril
# halle
# tara
# alosy
# eave
# stona
# ceanto
# helen
# jaxe
# sha
# crell
# n
# iter: 488000, loss: 11.932715
#
# ezmarionet
# jonethia
# kolmerton
# hal
# julison
# cin
# judith
# gayla
# penni
# johnfyd
# hay
# sandy
# altayse
# amila
# pember
# dina
# ioune
# merayd
# garrie
# anna
# harle
# lennett
# riesty
# brine
# lbora
# danio
# goeg
# baivia
# valivia
# mina
# m
# iter: 488500, loss: 10.626998
# quispe
# jurittin
# tytal
# flena
# wilissa
# kerry
# tord
# maurod
# eflen
# maur
# denorma
# larriana
# patty
# brancene
# abertha
# mariup
# jarrya
# dami
# mari
# sherencelen
# alica
# bridi
# kardy
# christin
# edguron
# malica
# derrika
# allen
# gay
# iter: 489000, loss: 9.256362
# g
# nika
# gayla
# bridoe
# mishiz
# handell
# taryan
# niton
# detti
# ismiro
# shaniell
# rudin
# kendar
# hola
# ysabelan
# lena
# shelegan
# velina
# caolistalie
# koly
# sleetana
# calin
# racharry
# marcia
# leeerr
# johney
# jaro
# sabry
# rollene
# s
# iter: 489500, loss: 11.952743
# fredroy
# stefpe
# seran
# tery
# yecis
# anna
# amilyana
# jerrinden
# edgin
# diana
# leurick
# hanton
# abbyna
# alphua
# martine
# roman
# zachy
# martin
# kathacotte
# jostean
# antamarna
# evegal
# norhon
# sherry
# loithan
# edwie
# esscerito
# jo
# iter: 490000, loss: 9.614199
# sexanseeman
# ginah
# kathera
# arissold
# iarose
# joylyn
# kiela
# loail
# callie
# laurius
# cortinice
# cleerra
# carlian
# jase
# gesa
# mara
# macioda
# oyad
# heled
# marisheril
# gievely
# luudam
# tebeca
# paton
# wavanela
# fashailer
# joheel
# iter: 490500, loss: 8.331094
# lopi
# koya
# jeanie
# kena
# carlyn
# cail
# carkiina
# leubrin
# don
# jaime
# kyllin
# teles
# breannielle
# gwente
# harrina
# mika
# yla
# ponya
# lice
# mandy
# geisha
# vilais
# micheell
# grog
# elian
# frany
# gregorenda
# cathlee
# jeany
# zylene
# c
# iter: 491000, loss: 13.912655
# catte
# karine
# ramind
# ranneph
# girgo
# juliec
# jayma
# yustyn
# lathie
# christal
# demilinda
# brian
# stephan
# lucie
# sharnna
# vedwin
# dann
# aumie
# roesla
# centin
# donga
# mathelma
# beandriell
# doveda
# kimbri
# kathiew
# brakl
# zaxana
# iter: 491500, loss: 8.781690
# in
# jackie
# laurio
# darior
# oansey
# reugon
# lorlene
# cecall
# scamesh
# angely
# leo
# esther
# briana
# lesyan
# shaton
# justi
# jahna
# sorta
# lenlem
# georgia
# vickie
# kathie
# madwis
# dilmien
# eanno
# anad
# jaimi
# mella
# maxalira
# stepha
# iter: 492000, loss: 12.070972
# ian
# cornyvan
# stovon
# trayl
# orfe
# suzanne
# lat
# mod
# rancenronne
# tamiah
# carie
# arista
# carenlon
# berto
# ciannne
# collo
# illas
# jenne
# cort
# perrett
# batty
# carl
# dryan
# larrandra
# christon
# lins
# sillienique
# kacilie
# amara
#
# iter: 492500, loss: 10.069997
# ames
# herton
# hminy
# hilcy
# carett
# alphus
# felext
# kristophal
# kaysa
# rosber
# flarry
# valarika
# naldo
# jael
# hado
# etune
# igaine
# cia
# solila
# lyssan
# choriyl
# anjeyan
# casmie
# jazeb
# ariso
# leona
# jeannie
# revo
# patricia
# natam
# iter: 493000, loss: 10.071014
#
# orra
# juce
# frevin
# corryn
# keiry
# tewna
# jean
# micka
# prestine
# thanda
# al
# braci
# carrel
# ourie
# lathia
# natlan
# jonelal
# telerah
# hrinathany
# bejaerma
# tariah
# royden
# willa
# dolok
# jase
# juanie
# jazey
# diol
# na
# alacy
# carlis
# iter: 493500, loss: 13.403672
# g
# kendosmie
# mayk
# kurleya
# sheole
# kathrian
# vudnay
# marison
# anna
# lice
# orgera
# annam
# ana
# melin
# alenia
# lioni
# nayanne
# cara
# shatlyn
# ala
# leus
# spence
# vani
# loring
# nve
# syspana
# charlis
# jess
# clivan
# lora
# ala
# abiga
# pe
# iter: 494000, loss: 8.715770
# on
# clake
# lewie
# ett
# pauley
# kancenta
# carlay
# georchamine
# demon
# christ
# keison
# marcele
# auaus
# syova
# gabki
# betl
# bertie
# zelitzay
# hanna
# shannie
# davin
# donorman
# amin
# sefanoe
# lucied
# lornandona
# talexandra
# helenn
# b
# iter: 494500, loss: 11.926067
# ana
# patrice
# corrin
# caden
# viccil
# felian
# grandon
# chroly
# julessa
# cherey
# juet
# selustingin
# johna
# lez
# jamie
# hallay
# donit
# hamber
# ganiretto
# rankille
# emalyana
# lamee
# ardelle
# leanella
# wart
# maurence
# charley
# rucki
# iter: 495000, loss: 7.701346
#
# damiarna
# harlal
# wilsia
# lynnke
# alelia
# chris
# ashurece
# collisco
# malione
# linces
# celenl
# billie
# curuilio
# jay
# gregwy
# joe
# maryn
# kenzamond
# jenniffa
# julia
# jees
# tolynna
# brandis
# epwalias
# antorina
# maxinory
# luena
#
# iter: 495500, loss: 6.875893
# uylesis
# durin
# lori
# canton
# wadoline
# kamina
# szilor
# kasen
# amicharl
# jasus
# jaslipha
# bpe
# amanya
# darlen
# derrie
# conerepa
# vicky
# steb
# joy
# jirgaeg
# theodo
# mancie
# fillce
# alix
# anah
# stimma
# gentthela
# len
# branda
# carl
#
# iter: 496000, loss: 10.352982
# sasan
# broyd
# allis
# feren
# anttupa
# robin
# vanase
# kylyn
# ashyanna
# maxysha
# idanie
# lawrand
# carral
# versa
# illes
# donnie
# saler
# marcis
# jacquelsefena
# masara
# romen
# coris
# tresten
# monerie
# caseb
# ashley
# berla
# kaylevin
# e
# iter: 496500, loss: 11.834154
#
# clauden
# augusty
# damire
# olfred
# quinda
# colond
# jade
# waydan
# ambarley
# cherticy
# irda
# dembren
# kura
# rylet
# jonis
# karvon
# chestino
# guissa
# roncy
# shantruy
# flory
# jane
# lay
# earl
# treyl
# harra
# comae
# audrid
# trek
# darree
#
# iter: 497000, loss: 12.994868
# ista
# christalline
# salfrey
# joest
# catrice
# russa
# callico
# eliza
# pillied
# cristhel
# rosuodaldy
# hayd
# karina
# joeyre
# amyzo
# brith
# kyla
# sheagh
# rulani
# pairea
# kaushuyra
# dalley
# ioann
# lynn
# famnel
# alwy
# lasean
# esugue
# s
# iter: 497500, loss: 10.599001
# vay
# judi
# tardon
# rey
# danis
# laurica
# greguro
# dechadola
# jomee
# doette
# shara
# lucett
# tobzy
# julie
# fregory
# joanno
# alora
# salvesina
# ellesta
# lendrel
# joe
# tawni
# azance
# jaliana
# chandar
# ivon
# rebni
# farrul
# anna
# alis
# vi
# iter: 498000, loss: 16.081339
# ko
# alfy
# michaileris
# jerendo
# rabetce
# crystin
# jenery
# omelia
# aiher
# vildin
# brony
# alysa
# lick
# rixian
# jomanton
# ryana
# joney
# evira
# vigrina
# layme
# prestini
# gennie
# leoneth
# gepariy
# fean
# tryns
# erne
# shon
# cecfir
# shan
# iter: 498500, loss: 6.178029
# e
# beina
# minny
# rydnor
# olima
# naida
# marvin
# fronna
# mirnon
# iara
# trence
# santa
# roses
# ruther
# josefmith
# erneste
# kelar
# earca
# karegges
# quenton
# kaugette
# aster
# trest
# vian
# kenna
# lurianor
# latrick
# baes
# beggra
# millie
#
# iter: 499000, loss: 10.683247
# arzann
# katissayve
# marlesia
# brandy
# jaffie
# ysarin
# angeel
# carhie
# caulenne
# ernerezle
# nanda
# michul
# vinton
# jana
# joeina
# shalemores
# brytt
# dobbie
# kathnice
# patten
# brancis
# keldor
# cleite
# lucodena
# bessuasha
# avena
#
# iter: 499500, loss: 11.861655
# r
# marely
# jackena
# loris
# merost
# villa
# cley
# lauro
# molcie
# patsorit
# roxana
# kelledo
# zay
# codrielben
# kernn
# sabrie
# leoni
# berain
# amirian
# angelli
# alay
# bewshe
# risharixy
# josxanie
# erne
# marvin
# rebera
# lilliann
# delore
# iter: 500000, loss: 11.223096
# ne
# brangyn
# paul
# meldila
# angelissepha
# cherlyn
# carvin
# day
# emanten
# miriolah
# sheron
# vivi
# ronald
# leilane
# jolie
# nitton
# alicia
# addreesanna
# luk
# jolandrla
# janel
# jessa
# rosefane
# collin
# alecandra
# spemcy
# aifelizal
# iter: 500500, loss: 10.492897
# ime
# jeliath
# christa
# jayley
# rezzesca
# alyvona
# rylo
# jimiy
# malina
# kintty
# dyuanat
# avice
# sheo
# sharnestar
# thilly
# kaisteve
# leonce
# kennie
# frence
# carolyn
# krist
# iveryn
# rose
# asha
# evileenter
# breinen
# ruye
# con
# maola
# iter: 501000, loss: 14.063425
# abriga
# reana
# beriana
# essie
# hay
# mbylorindabyo
# fayd
# daverne
# jessandian
# roberca
# almjey
# kryona
# cherredn
# ert
# shan
# marfon
# hwnah
# joanna
# benal
# cadynce
# bunelt
# victirie
# annne
# don
# beidenian
# dexinah
# landy
# katelan
# iter: 501500, loss: 12.554311
# ida
# ahord
# andra
# dilore
# abberly
# aidarie
# ghigeis
# evane
# cyly
# paty
# eleiah
# mascolen
# kenah
# rique
# mondy
# selvine
# katarie
# doney
# adresly
# penty
# domy
# ander
# lina
# cwilyn
# gilahia
# bern
# daina
# evira
# willy
# sonah
# gaelon
#
# iter: 502000, loss: 6.567367
# n
# brendwith
# franky
# beona
# anry
# aselyn
# trayel
# brita
# rhondy
# timmora
# phelle
# theary
# lonet
# hastine
# dail
# shaune
# jayla
# maria
# samany
# mollis
# windra
# mela
# dalin
# camuly
# gassice
# ray
# barlaygene
# grego
# marion
# marces
# g
# iter: 502500, loss: 6.503823
# ia
# geytha
# carla
# rolan
# asesha
# matwilli
# joriney
# shawn
# adma
# ael
# emmin
# anha
# sha
# petry
# jania
# carilis
# erine
# sharelon
# jaskiann
# esther
# jacquie
# rancyn
# edene
# joyl
# henelma
# juley
# carle
# clackis
# berna
# dwardo
# rogerl
# iter: 503000, loss: 7.652197
# ia
# melane
# carric
# angeli
# augusfan
# hudres
# tyrope
# donetta
# julie
# cole
# sconaly
# louit
# pamala
# helyn
# lonia
# becuilen
# katrin
# cady
# shallyn
# terres
# jessim
# marcie
# roighah
# lank
# danie
# andra
# aonan
# linder
# tyanor
# andra
#
# iter: 503500, loss: 10.500179
# enne
# domine
# mudeen
# dulif
# ydrah
# syane
# dellan
# carly
# fludel
# garel
# jalvie
# jillexanna
# dianttophelle
# clae
# shannig
# maursvin
# confera
# koymie
# pedrian
# kkick
# fabel
# gator
# vikk
# carmond
# cliffany
# allisan
# tikery
# elias
# iter: 504000, loss: 10.764951
#
# fary
# ranjer
# dilah
# ston
# hilathanene
# lake
# tegrangy
# ailer
# zucie
# patla
# su
# alma
# abeth
# levia
# maria
# saylen
# ned
# curisson
# pateida
# lacy
# elien
# cliffan
# hernne
# trey
# armot
# cammy
# lura
# stephon
# milton
# pegrin
# connor
# e
# iter: 504500, loss: 9.689629
#
# brada
# marleee
# yelen
# kaicy
# layn
# omyna
# malvid
# alesarah
# shell
# every
# bradi
# sharley
# chrilip
# ricky
# frankris
# jolia
# padinie
# ayah
# sed
# jennie
# grena
# braylen
# johne
# leinie
# margia
# giloa
# margia
# cllith
# methie
# paulid
# iter: 505000, loss: 10.346263
#
# melen
# janie
# paul
# lst
# rucha
# stamporene
# chaels
# fouil
# fred
# sevan
# chencie
# aida
# alex
# jean
# carica
# arhbett
# esecia
# kallesa
# thewbek
# hrence
# adalla
# tenerezaa
# luisha
# raymeron
# tard
# elie
# keila
# liel
# robrany
# broyvon
# iter: 505500, loss: 7.781793
# ie
# seta
# zace
# edea
# osha
# cadene
# aupielka
# tancy
# tyra
# celexia
# tauviona
# cosa
# elina
# christeray
# oldon
# recna
# jordoth
# darlene
# esse
# kaianna
# kamirga
# ruslin
# hoyas
# glon
# fendama
# sharian
# roreon
# simbert
# jusisce
# celie
# iter: 506000, loss: 14.150258
# stera
# suddo
# meressophia
# astriza
# liol
# jerr
# dionya
# suz
# barmien
# christosha
# marah
# shara
# cassie
# codie
# ramberteder
# andel
# pethyn
# azkherda
# runeslie
# bryda
# phille
# loline
# vellan
# shane
# marienna
# andoe
# clidwal
# edes
# iter: 506500, loss: 9.168280
# xenika
# ebent
# wiellie
# jemfie
# suel
# sostayd
# arlance
# opella
# ssanta
# marlli
# katie
# ctarrillian
# andres
# breddia
# hirel
# marton
# rashiel
# teldue
# conia
# jady
# bviton
# jaknit
# jakira
# vian
# darlene
# catherite
# kameelique
# lic
# iter: 507000, loss: 19.255483
# rrail
# annela
# falleushe
# leva
# alfren
# deshe
# shesene
# grand
# jakae
# jennia
# jemelly
# dferfina
# shanelie
# lacie
# ssevan
# ravuanka
# jaymeanna
# denjaddivi
# gracic
# bredton
# freda
# frankie
# lacy
# amin
# brimker
# dianne
# shelen
# dw
# iter: 507500, loss: 11.109160
# aymia
# elaire
# jaylar
# tomy
# lisze
# chriona
# melique
# natale
# althella
# carrick
# iondrd
# ertie
# hreet
# geverol
# emeya
# ronettel
# brevie
# shel
# annttanyah
# kewin
# jyana
# gerexice
# chacrits
# rachera
# rylah
# jenelle
# jadaid
# kolly
# iter: 508000, loss: 10.523812
#
# gaora
# nyca
# mikarin
# jucille
# kisley
# doninio
# altin
# lucion
# wildis
# horht
# eristeph
# brailen
# daina
# tara
# katie
# bundon
# cossel
# cesisan
# scemily
# mella
# dany
# cassie
# anarundo
# albrie
# derald
# samuann
# tatya
# shaldr
# aah
# m
# iter: 508500, loss: 11.495058
# n
# dodgina
# alenica
# yatt
# yran
# jean
# royse
# arine
# charley
# katlinda
# alfreana
# joskie
# maryly
# killsiannette
# vonnik
# helon
# louis
# alasha
# suditone
# jzandy
# lania
# frandrio
# anne
# joanna
# keannen
# brinab
# issapher
# caisas
# y
# iter: 509000, loss: 14.144005
# eredney
# keydonst
# randar
# erissa
# anget
# yefolyn
# kaish
# alyn
# ardan
# corcesta
# abela
# mulyna
# tawis
# seazan
# conite
# fondres
# artensea
# danie
# briana
# margin
# gabian
# megpe
# tolynn
# donica
# doria
# topa
# anne
# victar
# mattil
# tr
# iter: 509500, loss: 11.489478
# rishi
# latte
# maxon
# marguret
# amela
# rak
# hodro
# anicia
# roder
# daren
# arbyl
# cloredy
# hudevan
# roanne
# tammerny
# stelby
# marcustine
# virus
# jargilin
# kaylye
# selen
# menesa
# christin
# martay
# helesse
# mariudal
# pristina
# marcy
# iter: 510000, loss: 18.511811
# onen
# sonjos
# broncenzol
# evian
# anneda
# anthoo
# lindrel
# arney
# arisa
# aloe
# suman
# randy
# lobert
# niclorie
# hayla
# kystoup
# maria
# marlyn
# rathelen
# elmille
# leurega
# emila
# renema
# dagis
# maky
# halae
# saruel
# jessen
# jay
# joan
# iter: 510500, loss: 16.472040
# on
# tore
# richalle
# gunse
# glenn
# nui
# janesison
# tondi
# juan
# migaeffry
# loren
# kinifen
# angadra
# claremie
# racko
# jene
# aryann
# rolene
# alystongran
# bott
# sarie
# maxila
# eloako
# essel
# jean
# sodiustenie
# selann
# elexie
# kaiton
# iter: 511000, loss: 10.248964
# ydire
# aly
# kayton
# josexanna
# rolel
# seda
# jodenzoele
# lyedy
# bonoy
# karie
# chany
# modda
# selana
# henela
# patlir
# anaha
# ycah
# eusste
# edege
# mella
# caselandy
# bit
# tamie
# alexanda
# belarisirez
# trevin
# myriel
# abyida
# shawcie
#
# iter: 511500, loss: 7.958791
#
# brielia
# adelyson
# darrielle
# aha
# gerfor
# jamie
# doried
# garson
# norianit
# jonill
# rohuel
# angeline
# clarien
# laureline
# emik
# isan
# barbie
# reann
# eden
# marth
# ura
# tricel
# mylene
# manniffrey
# sonhi
# adalison
# frednand
# aibe
# iter: 512000, loss: 8.759503
# ia
# denyalyn
# tisa
# angelice
# acifforgia
# presto
# zalvin
# gania
# broy
# aunne
# daza
# bren
# mangifery
# stephon
# esizetha
# hear
# emoly
# caley
# gonsten
# cherielie
# tren
# dany
# kenor
# jeannie
# ferrcian
# cicmin
# pim
# beccamincia
# stas
# iter: 512500, loss: 11.735398
# naria
# velvina
# alees
# dennie
# patty
# aru
# sam
# vilah
# shealey
# harent
# karin
# kemaya
# marcele
# myrea
# connie
# shany
# ernell
# lana
# tury
# bayna
# ivernett
# donardel
# joris
# banmie
# lucy
# ginbfrey
# angelin
# annie
# danoth
# tracy
# mac
# iter: 513000, loss: 10.338591
# anna
# finton
# addo
# trebe
# hacaya
# caime
# lulion
# brandi
# tenna
# adin
# susin
# penerlo
# hewerta
# amaina
# helen
# conceri
# kers
# hvos
# terrequs
# flelvy
# geoffred
# kaulerie
# joni
# marvin
# christar
# darrine
# joselin
# claystine
# rene
#
# iter: 513500, loss: 19.178704
#
# montil
# benton
# regis
# aughonete
# casmin
# aile
# trick
# bettery
# phila
# macither
# aide
# daydaug
# shavalinna
# ton
# refondoe
# evin
# kella
# aleet
# vavonna
# valenaddie
# adelle
# abbrin
# evonne
# motri
# rayce
# naxophan
# karam
# wendol
#
# iter: 514000, loss: 5.171557
# atalie
# alerie
# mario
# joen
# rayd
# ildan
# belby
# katen
# rodva
# penny
# frannya
# amin
# carmela
# mristella
# ileanna
# maria
# arsher
# stigrie
# ackley
# shulla
# marl
# conna
# monwil
# jessey
# beaesme
# alyx
# caeld
# sselbina
# heennia
# varam
# iter: 514500, loss: 13.855288
# ahna
# maurel
# mith
# dott
# clish
# audisha
# bot
# penesha
# loana
# alspa
# donard
# chres
# smontha
# domarie
# chon
# nana
# sarvan
# bria
# shawny
# ginry
# clane
# bayda
# mamilaw
# jesey
# paulie
# perrassandome
# kies
# darla
# ellenjo
# claigrick
#
# iter: 515000, loss: 9.127986
# dobondl
# adrise
# keinabera
# fennia
# miedo
# desores
# jessie
# ete
# emilow
# jonnie
# jessy
# johel
# elisa
# ylynne
# bennie
# rosa
# natart
# tommannestine
# marth
# tonia
# mangon
# yuka
# angelt
# joil
# adcel
# hunith
# iva
# bellin
# wilmond
# ron
# iter: 515500, loss: 13.833491
# on
# kaiatrritte
# lorelia
# paylen
# dyaune
# gisebette
# joys
# vettie
# alejandan
# tonas
# jamofrandra
# carmi
# madilic
# neonne
# leendy
# shannald
# killie
# belioney
# nadarie
# dila
# marielpia
# liannah
# uanton
# bride
# carolyn
# culle
# le
# iter: 516000, loss: 9.752141
# am
# fredest
# fre
# tayvan
# abbiona
# luerza
# timam
# janon
# walren
# ilaine
# martin
# nica
# haleria
# vila
# irin
# julia
# bobby
# denis
# mandil
# helby
# ereldor
# maxina
# lesic
# annis
# maniah
# sabiy
# donissue
# danie
# clynna
# eva
# kara
# ronie
# iter: 516500, loss: 13.861758
# tathan
# dyanna
# marlyn
# chriel
# jessic
# ternisui
# rois
# brito
# marjoristaiki
# bebercirette
# allest
# broyd
# andreen
# soma
# rex
# pathyn
# ales
# talyn
# ryron
# vioga
# kanella
# linziste
# phon
# barl
# witton
# ema
# bennitran
# fran
# harri
# iter: 517000, loss: 10.432056
#
# jacquelisha
# raudie
# kaylatie
# reger
# victorra
# kristavia
# amiah
# johnned
# herlae
# mabin
# kember
# helane
# delalyuge
# gepord
# geonasoe
# rayle
# shaler
# maysel
# annes
# mag
# bathery
# jakquel
# jees
# baller
# steri
# kensryna
# rosema
# iter: 517500, loss: 10.322122
# jean
# brieston
# kutry
# boy
# derold
# juliol
# halle
# rayven
# sieserl
# raysa
# juandree
# lillie
# andree
# ando
# wonet
# leonaidi
# kennelion
# lilip
# elmie
# luistilian
# margine
# edy
# bernedoa
# sonei
# lope
# dawik
# donidseil
# nuriell
# dwr
# iter: 518000, loss: 11.921011
# ma
# jernett
# nith
# con
# nevinte
# curas
# tory
# marvin
# seline
# leo
# luna
# alechill
# johnn
# deltor
# oll
# sobbife
# cherle
# luccissa
# derna
# simanthano
# rawnya
# edith
# galela
# alexya
# isay
# las
# nucki
# ada
# ierrie
# scentan
# channa
# ebu
# iter: 518500, loss: 10.969731
# tin
# manthelelly
# gina
# jare
# spanna
# rona
# dangy
# sceandrissabely
# roebine
# candon
# ruszana
# gdely
# reel
# juanina
# myllisan
# joe
# milia
# teffanie
# lawine
# wodi
# vynne
# tamay
# eharick
# betten
# vertary
# jorian
# brolia
# girgar
# eu
# iter: 519000, loss: 11.206151
# an
# aidel
# jimmy
# sharnat
# kalexaphersevis
# marine
# edronie
# walton
# wavin
# tine
# jerrina
# edwin
# teren
# sharie
# wend
# gerron
# bunel
# lanie
# michane
# tamis
# linson
# ioeley
# miany
# obin
# wila
# sida
# margla
# ekon
# chereld
# donnise
#
# iter: 519500, loss: 12.748529
# mara
# isudie
# olis
# ranielleneca
# christon
# rancevi
# katine
# cherry
# trac
# isha
# nanda
# ashlyna
# annie
# makar
# bernnie
# dasrai
# shanetta
# cachan
# mar
# jorelyn
# briariah
# darrillia
# peggis
# marcat
# darlt
# hudwicuilan
# charsonia
# iter: 520000, loss: 8.130877
# ocio
# moghann
# nadelyna
# delariscrais
# oya
# brahly
# jandy
# ceuzine
# alana
# sada
# elian
# trialey
# lauriann
# cherly
# micka
# jaco
# bern
# ffeturye
# rogine
# call
# falva
# mondy
# rachero
# haylisti
# sellie
# bryannece
# marittaney
# vanie
# iter: 520500, loss: 13.081961
# lta
# arhan
# christarle
# macua
# nicgie
# lisais
# annvalishah
# banmin
# christogen
# vavenne
# jeary
# debina
# clari
# hudree
# kayda
# karelia
# geothelis
# rohnn
# shewes
# phildargino
# gette
# arnes
# autter
# kaylan
# gwene
# kamenh
# johan
# h
# iter: 521000, loss: 13.820901
